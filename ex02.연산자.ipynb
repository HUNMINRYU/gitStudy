# %%
7//4
7%4
# Out:
# 3

# %% [markdown]
# ##### 연산자 종류
# ![image-2.png](attachment:image-2.png)

# %%
#문자열 더하기(이어붙이기)
str1 = "안녕"
str2 = "하세요"

str1 + str2
# Out:
# '안녕하세요'

# %%
str1 = "10"
str2 = "7"

str1 + str2
# Out:
# '107'

# %%
#숫자와 문자열 더하기

num1 = 10
str2 = "7"

#형변환을 통해서 정수를 문자열로, 문자열을 정수로 변경가능
#int(): int형으로 강제형변환
print(num1 + int(str2))

#type(): 타입 확인
print(type(str2))

#str(): str형으로 강제형변환
print(str(num1) + str2)
# Out:
# 17
# <class 'str'>
# 107

# %%
#문자열 곱셈(횟수만큼 이어붙인다!)
'*' * 8
# Out:
# '********'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1,num2 = 23,3
print(f"두수의 ".format())
print(f"두수의 ".format())
print(f"두수의 ".format())
print(f"두수의 ".format())
print(f"두수의 ".format())
print(f"두수의 ".format())
print(f"두수의 ".format())

# %%
#input 함수
#키보드로 입력할 수 있는 함수
#자바의 scanner와 같은 기능

#※ input함수 주의사항!
# 1.input함수의 반환값은 문자열(String)형이다!
# 2.연산을 수행해야 할 경우, 형변환이 필요!
# 3.입력을 수행해야지만 다음 코드로 진행가능! 
num1 = int(input("첫번째 정수를 입력해 주세요>>"))
num2 = int(input("두번째 정수를 입력해 주세요>>"))

#alt 드래그
print(f")
print(f")
print(f")
print(f")
print(f")
print(f")
# Out:
# 첫번째 정수를 입력해 주세요>>1
# 두번째 정수를 입력해 주세요>>3

# %%
#복합 대입 연산자: 누적할 때 사용한다!

# %%
#삼항 연산자
# a if 조건식 else b
# true  -> a(왼쪽)
# false -> b(오른쪽)

score = 55
'합격' if score >=60 else '불합격'
# Out:
# '불합격'

# %%
if score=55:
